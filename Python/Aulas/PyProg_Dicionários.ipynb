# %% [markdown]
# #DICIONÁRIOS

# %%
#EXEMPLO 01

almoco = {'comida': "Lanche", "bevida": "Água", "sobremesa": "Pudim"}
print(almoco)
print(type(almoco))
# Out:
# {'comida': 'Lanche', 'bevida': 'Água', 'sobremesa': 'Pudim'}
# <class 'dict'>

# %%
#EXEMPLO 02

almoco = {
    "comida": "Lanche",
    "bebida": "Água",
    "sobremesa": "Pudim"
    }

print(almoco.items())
# Out:
# dict_items([('comida', 'Lanche'), ('bebida', 'Água'), ('sobremesa', 'Pudim')])

# %%
#EXEMPLO 03

print(almoco.keys())
# Out:
# dict_keys(['comida', 'bebida', 'Sobremesa'])

# %%
#EXEMPLO 04

print(almoco.values())
# Out:
# dict_values(['Lanche', 'Água', 'Pudim'])

# %%
#EXEMPLO 05

print(almoco['comida'])
# Out:
# Lanche

# %%
#EXEMPLO 06

for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>12}")
# Out:
# comida       |       Lanche
# bebida       |         Água
# Sobremesa    |        Pudim

# %%
#EXEMPLO 07 ALTERAR VALORES NO DICIONÁRIO

almoco['bebida'] = "Suco de laranja"

for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>20}")
# Out:
# comida       |               Lanche
# bebida       |      Suco de laranja
# Sobremesa    |                Pudim

# %%
#EXEMPLO 08 REMOVER ITENS DO DINCIONÁRIO

del almoco["sobremesa"]

for chave, valor in almoco.items():
    print(f"{chave:12} | {valor:>20}")

# %%
#EXEMPLO 09

estado = {}
brasil = []

for e in range(2):
    estado['uf'] = input("Digite a UF: ")
    estado['sigla'] = input("Digite a sigla: ")
    brasil.append(estado.copy())


print(brasil)
print(brasil[0]['sigla'])

# %%
# EXEMPLO 10

for e in brasil:
    for valor in e.values():
        print(valor)

# %%
# DESAFIO 01
"""
Dada a lista 'almoco', mostre a comida de Catarina.
"""
almoco = [
    {"nome":"Leandro", "comida": "Lanche", "bebida": "Suco de Laranja"},
    {"nome":"Celia", "comida": "Lasanha", "bebida": "Suco de uva"},
    {"nome":"Catarina", "comida": "Pizza", "bebida": "Coca-Cola"}
]

print(almoco[2]['comida'])
# Out:
# Pizza

# %%
# DESAFIO 02
"""
Com a lista do DESAFIO anterior, exiba uma lista com o nome da pessoa e o que ela come.
"""
almoco = [
    {"nome":"Leandro", "comida": "Lanche", "bebida": "Suco de Laranja"},
    {"nome":"Celia", "comida": "Lasanha", "bebida": "Suco de uva"},
    {"nome":"Catarina", "comida": "Pizza", "bebida": "Coca-Cola"}
]


for i in range(len(almoco)):
    print(f"{almoco[i]['nome']} - {almoco[i]['comida']}")
# Out:
# Leandro - Lanche
# Celia - Lasanha
# Catarina - Pizza

# %%
# DESAFIO 03
"""
Faça  um programa que leia o nome e média de um aluno, guardando também a situação em um dicionário.
(Abaixo de 5: Reprovado | entre 5 e 6,9: Exame | 7: acima Aprovado)
No final mostre o conteúdo da estrutura na tela.
"""

x = input("Insira seu nome: ").capitalize()
y = float(input("Digite sua média: "))
z = " "

if y < 5:
    z = "Reprovado"
elif y >= 5 and y <=6.9:
    z = "Exame"
else:
    z = "Aprovado"

data = {"nome": x, "nota":y, "situação": z}
print("\n", data)

# %%
# DESAFIO 04
"""
Faça com que o programa anterior possa cadastrar uma quantidade de alunos escolhida pelo usuário.
No final apresente as informações tabuladas.
"""
from google.colab import output

n = int(input("Quantos alunos deseja cadastrar? "))
z = " "
data = {}
lista = []
for i in range(n):
    x = input("Insira seu nome: ").capitalize()
    y = float(input("Digite sua média: "))

    if y < 5:
        z = "Reprovado"
    elif y >= 5 and y <=6.9:
        z = "Exame"
    else:
        z = "Aprovado"

    data = {"nome": x, "nota":y, "situacao": z}
    lista.append(data)

output.clear()
for i in range(len(lista)):
    print(f"Nome: {lista[i]['nome']} - Nota: {lista[i]['nota']} - Situação: {lista[i]['situacao']}")
# Out:
# Nome: Victor wilker - Nota: 10.0 - Situação: Aprovado
# Nome: Gabriel - Nota: 7.0 - Situação: Aprovado
# Nome: Joana - Nota: 2.0 - Situação: Reprovado
# Nome: Maria - Nota: 4.0 - Situação: Reprovado
# Nome: Jonas - Nota: 6.0 - Situação: Exame
# Nome: Rayssa - Nota: 10.0 - Situação: Aprovado
