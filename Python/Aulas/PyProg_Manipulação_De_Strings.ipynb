# %% [markdown]
# #MANIPULAÇÃO DE STRINGS

# %%
# FATIAMENTO DE STRINGS

texto = "Curso de Python"

print(texto[6])      #7º caractere
print(texto[9:15])      #10º ao 15º caractere
print(texto[9:15:2])      #10º ao 15º caractere
print(texto[:5])      #Até o 5º caractere
print(texto[9:])      # 10º caractere em diante
print(texto[::-1])      # Inverter o texto

nome = "Victor Wilker"
print(nome[::-1])

# %%
# ANÁLISE DE STRINGS

frase = "SENAI Ary Torres"

# Tamanho da String
print(len(frase))

# Contar caracteres
print(frase.count('e'))

# Encontrar Index (retorna -1 se não encontrar)
print(frase.find('r'))

# Encontrar Index (a partir da direita)
print(frase.rfind('r'))

# Encontrar Index (gera erro se não encontrar)
print(frase.index('r'))

#Verificar existência
print("Ary" in frase)

# %%
#TRANSFORMAÇÃO DE STRINGS

# Maiúsula
print(frase.upper())

# Minúscula
print(frase.lower())

# Primeira da Frase em maiúscula
print(frase.capitalize())

# Primeira de cada palavra em maiúscula
print(frase.title())

# %%
# TRANSFORMAÇÃO DE STRINGS 2

#Substituir palavras
print(frase.replace('SENAI' , 'ESCOLA'))

frase = "oi  SENAI Ary  Torres  oi"

# Retirada/Limpeza
print(frase.strip()) # Limpa espaços antes e depois

print(frase.strip('oi')) #Limpar caracteres

frase2 = "https://google.com/h"
print(frase2.rstrip('h'))
print(frase2.lstrip('h'))

# %%
# DIVISÃO E JUNÇÃO DE STRINGS

texto = "SENAI Ary Torres"

# Juntar caracteres com delimitador
print('.'.join(texto))

# Dividir palavras em lista
print(texto.split())
texto = texto.split()

print(', '.join(texto))

# Acesso a lista
print(texto[1])

# Acesso ao último item da lista
print(texto[-1])
# Out:
# S.E.N.A.I. .A.r.y. .T.o.r.r.e.s
# ['SENAI', 'Ary', 'Torres']
# SENAI, Ary, Torres
# Ary
# Torres

# %%
##### Teste de Limpeza#####

novoTexto = 'oi SENAI   Ary   Torres  oi'
print(type(novoTexto))
novoTexto = novoTexto.strip('oi').split()
print(' '.join(novoTexto))

# %% [markdown]
# # DESAFIOS

# %%
# DESAFIO 1

"""
Crie um programa que leia o nome completo de uma pessoa e mostre:
 	O nome com todas as letras maiúsculas
 	O nome com todas as letras minúsculas
 	Quantas letras ao todo (sem considerar espaços)
 	Quantas letras tem o primeiro nome
"""

nome = input("Insira seu nome completo: ")

print(nome.upper())
print(nome.lower())
print(len(nome.replace(' ', '')))
print(len(nome.split()[0]))
# Out:
# Insira seu nome completo: victor wilker de andrade maurício
# VICTOR WILKER DE ANDRADE MAURÍCIO
# victor wilker de andrade maurício
# 29
# 6

# %%
# DESAFIO 2

"""
Faça um programa que leia um numero de quatro dígitos entre 1000 a 9999 e mostre na tela
cada um dos dígitos separados.
Ex: Digite um numero: 1979

Unidade: 9
Dezena: 7
Centena: 9
Milhar: 1
"""

n = input("Digite um numero de quatro dígitos entre 1000 e 9999: ")

print(f"Unidade: {n[3]}")
print(f"Dezena: {n[2]}")
print(f"Centena: {n[1]}")
print(f"Milhar: {n[0]}")
# Out:
# Digite um numero de quatro dígitos entre 1000 a 9999: 1923
# Unidade: 3
# Dezena: 2
# Centena: 9
# Milhar: 1

# %%
# DESAFIO 3

"""
Faça um programa que leia uma frase pelo teclado e mostre:

Quantas vezes aparece a letra "A"
Em que posição ela aparece a primeira vez
Em que posição ela aparece a ultima vez
"""

frase = input("Insira uma frase: ").upper()

print(frase.count('A'))
print(frase.find('A')+1)
print(frase.rfind('A')+1)
# Out:
# Insira uma frase: a bala
# 3
# 1
# 6

# %%
# DESAFIO 1 v2

nome = input("Insira seu nome completo: ")

print(f"Nome Maiúsculo: {nome.upper()}")
print(f"Nome Minúsculo: {nome.lower()}")
print(f"Lestras no nome: {len(nome.replace(' ', ''))}")
print(f"Letras no 1° nome: {len(nome.split()[0])}")

# %%
# DESAFIO 04

"""
Faça um programa que leia o nome completo de uma pessoa, mostrando em seguida o primeiro
e o ultimo nome separadamente.

Exemplo: Leandro Gomes Andrade

Primeiro: Leandro
Ultimo: Andrade
"""

nome = input("Insira seu nome completo: ")

print(f"Primeiro: {nome.split()[0]}")
print(f"Ultimo: {nome.split()[-1]}")

# %%
# DESAFIO 05

frase = input("Insira uma frase: ").upper()
letra = input("Insira uma letra: ").upper()

print(frase.count(letra))
print(frase.replace(' ', '').find(letra)+1)
print(frase.replace(' ', '').rfind(letra)+1)
# Out:
# Insira uma frase: a bala
# Insira uma letra: a
# 3
# 1
# 5
