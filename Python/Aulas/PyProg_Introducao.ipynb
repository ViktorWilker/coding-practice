# %%
print("Hello, world!")

# %%
print("victor wilker")

# %%
nome = "victor wilker"
print(nome)

# %% [markdown]
# **Algorítimo:** Montar um lanche
#
# **Passo 1:** Pegar o pão
#
# **Passo 2:** Se o pão estiver bom, ir para o próximo passo, se não, voltar para o passo 1
#
# **Passo 3:** Pegar ingredientes desejados
#
# **Passo 4:** Se o ingrediente estiver bom, ir para o próximo passo, se não, voltar para o passo 3
#
# **Passo 5:** colocar ingredientes no pão
#
# **Passo 6:** Se estiver completo vá para o passo 8, se não, vá para o passo 7
#
# **Passo 7:** voltar para o passo 3
#
# **Passo 8:** comer e ser feliz

# %% [markdown]
# ABSTRAÇÃO LÓGICA
# -----------------
#
# Um recipiente que recebe a água quente
#
# Um recipiente que recebe os grãos
#
# Um motor que tritura o café
#
# Uma jarra que armazena o conteúdo resultante

# %% [markdown]
# LÓGICA DE PROGRAMAÇÃO | BARRIL
#
# **Passo 1:** Passar 3L do barril C para o A
#
# **Passo 2:** Passar 1L B para o A

# %%
#TROCA DE VALORES: VÁRIAVEIS A e B

a = 5
b = 2
c = 0

c = b
b = a
a = c


print(a)
print(b)

# %%
#TROCA DE VALORES: VÁRIAVEIS A e B (Simultânea)

a = 5
b = 2
c = 0

a, b = b, a


print(a)
print(b)

# %%
#ÁLGEBRA BOOLEANA

a = False
b = True

print(a and b) #False
print(a or b) #True
print(not a) #True

# %%
#EXEMPLO IF

nota = int(input("insira sua nota: "))
frequencia = int(input("insira sua frequencia: "))

if nota > 6 and frequencia >= 75:
    print("Aprovado")
else:
    print("Reprovado")

# %%
#EXEMPLO IF 02

idade = 25

if idade >= 18:
    print("pó votar")
else:
    print("pó votar n")

# %%
#OPERADORES ARITMÉTICOS


a = 10
b = 3

print(a + b)        #13   (adição)
print(a - b)        #7    (subtração)
print(a * b)        #30   (multiplicação)
print(a / b)        #3.3  (divisão)
print(a // b)       #3    (divisão inteira)
print(a % b)        #1    (módulo)
print(a ** b)       #1000 (potência)
print(a ** (1/b))   #2.14 (raiz)

# %%
#OPERADORES RELACIONAIS OU DE COMPARAÇÃO

a = 10
b = 3

print(a == b) #False (igual)
print(a != b) #True (diferente)
print(a > b) #True (maior)
print(a < b) #False (menor)
print(a >= b) #True (maior ou igual)
print(a <= b) #False (menor ou igual)

# %%
#OPERADORES LÓGICOS OU BOOLEANOS

a = False
b = True

print(a and b) #False (e)
print(a or b) #True (ou)
print(not a) #True (negação/inverso)

# %%
#OPERADORES DE ATRIBUIÇÃO

a = 10
a += 2
print(a) # 12

a = 10
a -= 2
print(a) # 8

c = 10
c *= c
print(c) # 100

d = 10
d /= 2
print(d) # 5.0

d = 10
d //= 2
print(d) # 5

d = 9
d %= 2
print(d) # 1

d = 10
d **= 2
print(d) # 100

# %%
#EXPRESSÕES

"""
1) PARÊNTESES
2) PÔTENCIA E RAIZ
3) MULTIPLICAÇÃO E DIVISÃO
4) ADIÇÃO E SUBTRAÇÃO
"""

print((2+2)*5**2)
print(((2+2)*5)**2)

# %%
# REFATORAÇÃO DE CÓDIGO

# ORIGINAL
a = 10
b = 20
c = a+b
print('Original', c)

# REFATORADO
def soma(x, y):
    return x+y

print('Refatorado', soma(20, 30))
